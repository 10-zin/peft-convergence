# %%
import torch

# %%
import os
cache_dir_path = "/home/hice1/tkaple3/scratch/hf-cache"
os.environ["HF_HOME"] = "/home/hice1/tkaple3/scratch/hf-cache"

# %%
import wandb
wandb.login()
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ### Full Finetuning

# %%
# !python peft_llama_v2_samsum.py \
    --model_name meta-llama/Llama-3.2-1B \
    --dataset_name samsum \
    --optimizer adamw \
    --lr_schedule warmup \
    --learning_rate 3e-5 \
    --weight_decay 0.01 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_121201-zff906ag
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_adamw_warmup_20250426_121201
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/zff906ag
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %% [markdown]
# ### Default LoRA

# %%
# !python peft_llama_v2_samsum.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --dataset_name samsum \
    --peft_method lora \
    --use_peft \
    --optimizer adamw \
    --lr_schedule warmup \
    --learning_rate 3e-4 \
    --weight_decay 0.01 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_123340-oeu5z1ar
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_adamw_warmup_20250426_123339
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/oeu5z1ar
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %% [markdown]
# ### AdaFactor

# %%
# !python peft_llama_v2_samsum.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --dataset_name samsum \
    --peft_method lora \
    --use_peft \
    --optimizer adafactor \
    --lr_schedule warmup \
    --learning_rate 3e-4 \
    --weight_decay 0.01 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_125502-qnd4r8i6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_adafactor_warmup_20250426_125502
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/qnd4r8i6
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %% [markdown]
# ### Lion Optimizer

# %%
# !python peft_llama_v2_samsum.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --dataset_name samsum \
    --peft_method lora \
    --use_peft \
    --optimizer lion \
    --lr_schedule warmup \
    --learning_rate 3e-4 \
    --weight_decay 0.01 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_131643-gmlld9l6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_lion_warmup_20250426_131643
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/gmlld9l6
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %% [markdown]
# ### CosineAnnealing LR Scheduler

# %%
# !python peft_llama_v2_samsum.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --dataset_name samsum \
    --peft_method lora \
    --use_peft \
    --optimizer adamw \
    --lr_schedule cosine \
    --learning_rate 3e-4 \
    --weight_decay 0.01 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_133801-uuj98tv6
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_adamw_cosine_20250426_133801
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/uuj98tv6
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %% [markdown]
# ### ReduceLROnPlateau LR Scheduler

# %%
# !python peft_llama_v2_samsum.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --dataset_name samsum \
    --peft_method lora \
    --use_peft \
    --optimizer adamw \
    --lr_schedule plateau \
    --learning_rate 3e-4 \
    --weight_decay 0.01 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_135955-bdhz8075
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_adamw_plateau_20250426_135954
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/bdhz8075
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %% [markdown]
# ### Lower LR

# %%
# !python peft_llama_v2_samsum.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --dataset_name samsum \
    --peft_method lora \
    --use_peft \
    --optimizer adamw \
    --lr_schedule warmup \
    --learning_rate 1e-4 \
    --weight_decay 0.01 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_142129-t16hpyrg
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_adamw_warmup_20250426_142129
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/t16hpyrg
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %% [markdown]
# ### Higher LR

# %%
# !python peft_llama_v2_samsum.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --dataset_name samsum \
    --peft_method lora \
    --use_peft \
    --optimizer adamw \
    --lr_schedule warmup \
    --learning_rate 1e-3 \
    --weight_decay 0.01 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_144244-oq6r5kmk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_adamw_warmup_20250426_144244
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/oq6r5kmk
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %% [markdown]
# ### Higher Weight Decay (0.1)

# %%
# !python peft_llama_v2_samsum.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --dataset_name samsum \
    --peft_method lora \
    --use_peft \
    --optimizer adamw \
    --lr_schedule warmup \
    --learning_rate 3e-4 \
    --weight_decay 0.1 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_150353-oynqcos4
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_adamw_warmup_20250426_150353
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/oynqcos4
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %% [markdown]
# # Lower Weight Decay (0.001)

# %%
# !python peft_llama_v2_samsum.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --dataset_name samsum \
    --peft_method lora \
    --use_peft \
    --optimizer adamw \
    --lr_schedule warmup \
    --learning_rate 3e-4 \
    --weight_decay 0.001 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_152529-bfpatq42
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_adamw_warmup_20250426_152528
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/bfpatq42
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %% [markdown]
# ### Plateau with ROGUE

# %%
# !python peft_llama_v2_samsum.py \
    --model_name "meta-llama/Llama-3.2-1B" \
    --dataset_name samsum \
    --peft_method lora \
    --use_peft \
    --optimizer adamw \
    --lr_schedule plateau \
    --learning_rate 3e-4 \
    --weight_decay 0.01 \
    --batch_size 16 \
    --num_epochs 15 \
    --max_samples 1000 \
    --log_wandb
# Out:
# wandb: Currently logged in as: tanvi-kaple14 (tkaple). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.18.7
# wandb: Run data is saved locally in /storage/ice1/6/9/tkaple3/DL_Project/wandb/run-20250426_154655-k8r8iqf1
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run llama1b_samsum_lora_adamw_plateau_20250426_154655
# wandb: ⭐️ View project at https://wandb.ai/tkaple/peft-convergence-llama-samsum
# wandb: 🚀 View run at https://wandb.ai/tkaple/peft-convergence-llama-samsum/runs/k8r8iqf1
# /home/hice1/tkaple3/.conda/envs/myenv/lib/python3.11/site-packages/transformers/models/auto/tokenization_auto.py:809: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...
